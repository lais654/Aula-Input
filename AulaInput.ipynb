# %% [markdown]
# <a href="https://colab.research.google.com/github/lais654/Aula-Input/blob/main/AulaInput.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input ("Digite o seu nome :")

print("O seu nome é :", nome)
# Out:
# Digite o seu nome :Matheus
# O seu nome é : Matheus

# %% [markdown]
# Atividade 1

# %%
valor1 = int(input("digite o seu valor:"))
valor2 = int(input("digite o seu valor:"))
resultado = valor1 + valor2
print (resultado)
# Out:
# digite o seu valor:20
# digite o seu valor:30
# 50

# %% [markdown]
# Atividade 2

# %%
valor1 = int(input("digite um numero:"))
valor2 = int(input("digite um numero:"))
resultado = valor1 - valor2
print (resultado)
# Out:
# digite um numero:15
# digite um numero:10
# 5

# %% [markdown]
# Atividade 3

# %%
valor1 = int(input("digite um numero:"))
valor2 = int(input("digite um numero:"))

soma = valor1 + valor2
subtracao = valor1 - valor2
multiplicacao = valor1 * valor2
div = valor1 / valor2
print("soma:", soma)
print("subtracao:", subtracao)
print("multiplicacao:", multiplicacao)
print("divisao:", div)
# Out:
# digite um numero:7
# digite um numero:14
# soma: 21
# subtracao: -7
# multiplicacao: 98
# divisao: 0.5

# %% [markdown]
# Atividade 4

# %%
nome = input("digite o seu nome:")
print ("Ola", nome, "seja bem vindo!")
# Out:
# digite o seu nome:Laís,
# Ola Laís, seja bem vindo!
